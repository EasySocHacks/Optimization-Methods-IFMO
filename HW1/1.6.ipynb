# %%
import warnings

import numpy as np

from HW1.coord_relaxer import LinearCoordRelaxer
from HW1.func_generator import generate_function
from HW1.gradient_descent import gradient_descent
from HW1.scheduler import ExponentialScheduler
from HW1.step_length_computer import WolfeStepLengthComputer
from HW1.visualize import draw_2D, draw_3D

# %%
func2d = generate_function(1, 0.1, 0.1, True)
draw_2D(func2d)
# Out:
# 0 +
# 0.05x0 +
# 0.03(x0*x0)

# %%
draw_3D(generate_function(2, 0.1, 0.1, True))
# Out:
# 0 +
# 0.04(x0*x1) +
# -0.04(x1*x1)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    for dim in range(1, 11):
        f = generate_function(dim, 0.1, 0.1)
        (xs, y), meta = gradient_descent(f,
                                         dim,
                                         iterations=7777,
                                         lr=0.88,
                                         eps=777e-4,
                                         scheduler=ExponentialScheduler(77, -0.0666),
                                         coord_relaxer=LinearCoordRelaxer(f,eps=1e-3,step_length_computer=WolfeStepLengthComputer(0.0001, 0.9, f))
                                         )
        print("For dim={}: {} steps with {} f-calls, {} g-calls".format(dim, len(meta["points"]), meta["function_call_count"], meta["gradient_call_count"]))
# Out:
# C:\Users\maxim\PycharmProjects\Optimization-Methods-IFMO\HW1\gradient_descent.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array([coord, f(coord)]).reshape(1, 2),
# For dim=1: 55 steps with 507 f-calls, 254 g-calls
# For dim=2: 81 steps with 1525 f-calls, 534 g-calls
# For dim=3: 7777 steps with 70721 f-calls, 23388 g-calls
# For dim=4: 7777 steps with 85792 f-calls, 23372 g-calls
# For dim=5: 7777 steps with 103352 f-calls, 23391 g-calls
# For dim=6: 7777 steps with 117554 f-calls, 23390 g-calls
# For dim=7: 7777 steps with 133285 f-calls, 23386 g-calls
# For dim=8: 7777 steps with 154381 f-calls, 23388 g-calls
# For dim=9: 52 steps with 1872 f-calls, 200 g-calls
# For dim=10: 7777 steps with 179607 f-calls, 23372 g-calls
