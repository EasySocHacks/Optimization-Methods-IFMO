# %%
import warnings

import numpy as np

from HW1.coord_relaxer import LinearCoordRelaxer
from HW1.func_generator import generate_function
from HW1.gradient_descent import gradient_descent
from HW1.scheduler import ExponentialScheduler
from HW1.step_length_computer import WolfeStepLengthComputer
from HW1.visualize import draw_2D, draw_3D

# %%
func2d = generate_function(1, 0.1, 0.1, True)
draw_2D(func2d)
# Out:
# 0

# %%
draw_3D(generate_function(2, 0.1, 0.1, True))
# Out:
# 0 +
# 0.00(x0*x0) +
# 0.09(x0*x1)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for dim in range(1, 11):
        f = generate_function(dim, 0.1, 0.1)
        (xs, y), meta = gradient_descent(f,
                                         dim,
                                         iterations=7777,
                                         lr=0.88,
                                         eps=777e-4,
                                         # scheduler=ExponentialScheduler(77, -0.0666),
                                         # coord_relaxer=LinearCoordRelaxer(f,eps=1e-3,step_length_computer=WolfeStepLengthComputer(0.0001, 0.9, f))
                                         )
        print("For dim={}: {} steps with {} f-calls, {} g-calls".format(dim, len(meta["points"]), meta["function_call_count"], meta["gradient_call_count"]))
# Out:
# For dim=1: 114 steps with 114 f-calls, 113 g-calls
# For dim=2: 51 steps with 51 f-calls, 50 g-calls
# For dim=3: 51 steps with 51 f-calls, 50 g-calls
# For dim=4: 52 steps with 52 f-calls, 51 g-calls
# For dim=5: 55 steps with 55 f-calls, 54 g-calls
# For dim=6: 179 steps with 179 f-calls, 178 g-calls
# For dim=7: 408 steps with 408 f-calls, 407 g-calls
# For dim=8: 83 steps with 83 f-calls, 82 g-calls
# For dim=9: 203 steps with 203 f-calls, 202 g-calls
# For dim=10: 1290 steps with 1290 f-calls, 1289 g-calls
# For dim=11: 7777 steps with 7777 f-calls, 7777 g-calls
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <module>
#       3 for dim in range(1, 21):
#       4     f = generate_function(dim, 0.1, 0.1)
# ----> 5     (xs, y), meta = gradient_descent(f,
#       6                                      dim,
#       7                                      iterations=7777,
#       8                                      lr=0.88,
#       9                                      eps=777e-4,
#      10                                      # scheduler=ExponentialScheduler(77, -0.0666),
#      11                                      # coord_relaxer=LinearCoordRelaxer(f,eps=1e-3,step_length_computer=WolfeStepLengthComputer(0.0001, 0.9, f))
#      12                                      )
#      13     print("For dim={}: {} steps with {} f-calls, {} g-calls".format(dim, len(meta["points"]), meta["function_call_count"], meta["gradient_call_count"]))
#
# File ~/Документы/git/Optimization-Methods-IFMO/HW1/gradient_descent.py:61, in gradient_descent(f, dim, coord, lr, iterations, check_batch, eps, scheduler, coord_relaxer)
#      58     if avg_changes < eps:
#      59         break
# ---> 61 (coord, _), relax_meta = coord_relaxer.relax(coord, lr, gradient(f, coord))
#      63 meta["function_call_count"] += relax_meta["function_call_count"]
#      64 if "gradient_call_count" in relax_meta:
#
# File ~/Документы/git/Optimization-Methods-IFMO/HW1/gradient.py:21, in gradient(f, coord, h)
#      18     h_vec = np.zeros(coord.shape)
#      19     h_vec[i] = h
# ---> 21     f_left[i] = f(coord - h_vec)
#      22     f_right[i] = f(coord + h_vec)
#      24 grad = (f_right - f_left) / (2 * h)
#
# File ~/Документы/git/Optimization-Methods-IFMO/HW1/func_generator.py:44, in func_scale_result.<locals>.<lambda>(coord)
#      37 def func_scale_result(prev_func, constant=1):
#      38     """
#      39     Wraps given function 'prev_func' by scaling its invocation result by scaling coefficient 'constant'
#      40     :param prev_func: function that computes some polynomial's value at given point
#      41     :param constant: scale coefficient
#      42     :return: the new function that like f(coordinate)='prev_func'(coordinate)*'constant'
#      43     """
# ---> 44     return lambda coord: prev_func(coord) * constant
#
# File ~/Документы/git/Optimization-Methods-IFMO/HW1/func_generator.py:26, in func_double.<locals>.<lambda>(coord)
#      16 def func_double(prev_func, i, j, constant=1):
#      17     """
#      18     Wraps function 'prev_func' with adding to its invocation result the value of 'i'-th point's coordinate
#      19       value multiplied by 'j'-th point's coordinate value and scaled by 'constant'
#    (...)
#      24     :return: the new function that like f(coordinate)='prev_func'(coordinate)+'constant'*coordinate['i']*coordinate['j']
#      25     """
# ---> 26     return lambda coord: np.abs(prev_func(coord) + coord[i] * coord[j] * constant)
#
# File ~/Документы/git/Optimization-Methods-IFMO/HW1/func_generator.py:26, in func_double.<locals>.<lambda>(coord)
#      16 def func_double(prev_func, i, j, constant=1):
#      17     """
#      18     Wraps function 'prev_func' with adding to its invocation result the value of 'i'-th point's coordinate
#      19       value multiplied by 'j'-th point's coordinate value and scaled by 'constant'
#    (...)
#      24     :return: the new function that like f(coordinate)='prev_func'(coordinate)+'constant'*coordinate['i']*coordinate['j']
#      25     """
# ---> 26     return lambda coord: np.abs(prev_func(coord) + coord[i] * coord[j] * constant)
#
# KeyboardInterrupt:
