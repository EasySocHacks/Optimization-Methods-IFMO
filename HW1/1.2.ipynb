# %%
import warnings

import numpy as np

from HW1.gradient_descent import gradient_descent
from HW1.visualize import draw_2D, draw_3D
from scheduler import *

# %% [markdown]
# # Example 1
#
# > $dim = 1$.
# >
# > $f(x) = {x^4 \over 1e7}$

# %%
def f(coord):
    return (coord[0] ** 4) / 1e7

# %%
draw_2D(f)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    (x, y), meta = gradient_descent(f, 1, lr=0.9, scheduler=ExponentialScheduler(10, -0.2))
    print(x, y)
    print(meta)

    draw_2D(f, meta["points"])
# Out:
# [47.63783542] 0.5150010076815428
# {'gradient_call_count': 10000, 'function_call_count': 10000, 'points': array([[array([56.34984523]), 1.0082562205528995],
#        [array([56.28543117]), 1.0036539291105089],
#        [array([56.22123775]), 0.9990830952340896],
#        ...,
#        [array([47.63926896]), 0.5150630011429469],
#        [array([47.6387911]), 0.5150423354121175],
#        [array([47.63831326]), 0.5150216709250164]], dtype=object)}

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    (x, y), meta = gradient_descent(f, 1, lr=0.9, scheduler=StepScheduler(50, 0.04))
    print(x, y)
    print(meta)

    draw_2D(f, meta["points"])
# Out:
# [-16.21422777] 0.006911703161767674
# {'gradient_call_count': 826, 'function_call_count': 827, 'points': array([[array([-17.11400702]), 0.008578410481303202],
#        [array([-17.11220252]), 0.00857479301879462],
#        [array([-17.11039859]), 0.008571177844116446],
#        ...,
#        [array([-16.21511453]), 0.006913215294834139],
#        [array([-16.21467113]), 0.0069124591662776454],
#        [array([-16.21422777]), 0.006911703161767674]], dtype=object)}

# %% [markdown]
# # Example 2
#
# > $dim = 2$.
# >
# > $f(x, y) = sin(x / 20) * cos(e + y / 20)$

# %%
def f(coord):
    return np.sin(coord[0] / 20) * np.cos(np.e + coord[1] / 20)

# %%
draw_3D(f)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    (xs, y), meta = gradient_descent(f, 2, lr=0.9, scheduler=ExponentialScheduler(100, -0.5))
    print(xs, y)
    print(meta)

    draw_3D(f, meta["points"])
# Out:
# [29.85115247  8.4338857 ] -0.9969396109739546
# {'gradient_call_count': 632, 'function_call_count': 633, 'points': array([[array([28.71370036,  8.4104972 ]), -0.990882498546836],
#        [array([28.71976186,  8.41062142]), -0.990923294419076],
#        [array([28.72580985,  8.41074538]), -0.9909639085836096],
#        ...,
#        [array([29.85080219,  8.43387848]), -0.9969382413833643],
#        [array([29.85097734,  8.43388209]), -0.9969389262551399],
#        [array([29.85115247,  8.4338857 ]), -0.9969396109739546]],
#       dtype=object)}

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    (xs, y), meta = gradient_descent(f, 2, lr=0.9, scheduler=StepScheduler(25, 0.004))
    print(xs, y)
    print(meta)

    draw_3D(f, meta["points"])
# Out:
# [31.29523208  8.92913724] -0.9997139384431937
# {'gradient_call_count': 2330, 'function_call_count': 2331, 'points': array([[array([26.39554684, 33.7455214 ]), -0.2925732777556999],
#        [array([26.39892291, 33.70396755]), -0.2945039691365503],
#        [array([26.40231888, 33.66243934]), -0.29643243950125014],
#        ...,
#        [array([31.2949129 ,  8.93036164]), -0.9997124233108459],
#        [array([31.2950726 ,  8.92974903]), -0.9997131818773113],
#        [array([31.29523208,  8.92913724]), -0.9997139384431937]],
#       dtype=object)}
