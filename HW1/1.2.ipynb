# %%
import warnings

import numpy as np

from HW1.gradient_descent import gradient_descent
from HW1.visualize import draw_2D, draw_3D
from scheduler import *

# %% [markdown]
# # Example 1
#
# > $dim = 1$.
# >
# > $f(x) = {x^4 \over 1e7}$

# %%
def f(coord):
    return (coord[0] ** 4) / 1e7

# %%
draw_2D(f)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    (x, y), meta = gradient_descent(f, 1, lr=0.9, scheduler=ExponentialScheduler(10, -0.2))
    print(x, y)
    print(meta)

    draw_2D(f, meta["points"])
# Out:
# [14.6746135] 0.004637315953691984
# {'gradient_call_count': 60, 'function_call_count': 61, 'points': array([[array([14.71867138]), 0.004693258072419291],
#        [array([14.71752347]), 0.0046917941322101794],
#        [array([14.71637582]), 0.004690330876878306],
#        [array([14.71522845]), 0.004688868305996437],
#        [array([14.71408134]), 0.004687406419137762],
#        [array([14.71293451]), 0.004685945215875818],
#        [array([14.71178794]), 0.004684484695784459],
#        [array([14.71064163]), 0.0046830248584377974],
#        [array([14.7094956]), 0.004681565703410452],
#        [array([14.70834984]), 0.004680107230277147],
#        [array([14.70720434]), 0.004678649438613124],
#        [array([14.7062667]), 0.004677456432079116],
#        [array([14.70532925]), 0.004676263881807772],
#        [array([14.70439197]), 0.00467507178756635],
#        [array([14.70345487]), 0.004673880149122429],
#        [array([14.70251795]), 0.004672688966243621],
# ...

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    (x, y), meta = gradient_descent(f, 1, lr=0.9, scheduler=StepScheduler(50, 0.04))
    print(x, y)
    print(meta)

    draw_2D(f, meta["points"])
# Out:
# /home/easyhacks/Документы/git/Optimization-Methods-IFMO/HW1/gradient_descent.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([coord, f(coord)]).reshape(1, 2),
# [0.22599119] 2.608350968570156e-10
# {'gradient_call_count': 50, 'function_call_count': 51, 'points': array([[array([0.2259914]), 2.6083605599866193e-10],
#        [array([0.22599139]), 2.6083603681577706e-10],
#        [array([0.22599139]), 2.608360176328945e-10],
#        [array([0.22599138]), 2.60835998450014e-10],
#        [array([0.22599138]), 2.6083597926713554e-10],
#        [array([0.22599138]), 2.608359600842592e-10],
#        [array([0.22599137]), 2.608359409013851e-10],
#        [array([0.22599137]), 2.60835921718513e-10],
#        [array([0.22599136]), 2.60835902535643e-10],
# ...

# %% [markdown]
# # Example 2
#
# > $dim = 2$.
# >
# > $f(x, y) = sin(x / 20) * cos(e + y / 20)$

# %%
def f(coord):
    return np.sin(coord[0] / 20) * np.cos(np.e + coord[1] / 20)

# %%
draw_3D(f)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    (xs, y), meta = gradient_descent(f, 2, lr=0.9, scheduler=ExponentialScheduler(100, -0.5))
    print(xs, y)
    print(meta)

    draw_3D(f, meta["points"])
# Out:
# /home/easyhacks/Документы/git/Optimization-Methods-IFMO/HW1/gradient_descent.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([coord, f(coord)]).reshape(1, 2),
# [-30.45750872 -29.27507875] -0.3106651967221967
# {'gradient_call_count': 10000, 'function_call_count': 10000, 'points': array([[array([-30.57370271, -11.31598409]), 0.548946583630555],
#        [array([-30.57266184, -11.35354994]), 0.5473764231001297],
#        [array([-30.57162266, -11.39116204]), 0.5458024035884685],
#        ...,
#        [array([-30.45747188, -29.27273141]), -0.3105537493760219],
#        [array([-30.45748416, -29.27351387]), -0.310590899438048],
#        [array([-30.45749644, -29.27429632]), -0.31062804855346543]],
#       dtype=object)}

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    (xs, y), meta = gradient_descent(f, 2, lr=0.9, scheduler=StepScheduler(25, 0.004))
    print(xs, y)
    print(meta)

    draw_3D(f, meta["points"])
# Out:
# /home/easyhacks/Документы/git/Optimization-Methods-IFMO/HW1/gradient_descent.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([coord, f(coord)]).reshape(1, 2),
# [30.97337656  8.29022265] -0.9997164893236572
# {'gradient_call_count': 2301, 'function_call_count': 2302, 'points': array([[array([8.18979723, 1.00169287]), -0.37073171361742957],
#        [array([8.22823496, 1.00822556]), -0.37242025652951877],
#        [array([8.26664546, 1.01478169]), -0.37410681369836524],
#        ...,
#        [array([30.97219273,  8.28975192]), -0.9997149706293089],
#        [array([30.97278726,  8.28998833]), -0.9997157338363405],
#        [array([30.97337656,  8.29022265]), -0.9997164893236572]],
#       dtype=object)}
